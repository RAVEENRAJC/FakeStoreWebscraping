# %%
# !pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: requests in c:\users\user\appdata\roaming\python\python312\site-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests) (2.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\appdata\roaming\python\python312\site-packages (from requests) (2025.1.31)
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
url="https://fakestoreapi.com/products"
responce=requests.get(url)
data=responce.json()
print(data[0])
# Out:
# {'id': 1, 'title': 'Fjallraven - Foldsack No. 1 Backpack, Fits 15 Laptops', 'price': 109.95, 'description': 'Your perfect pack for everyday use and walks in the forest. Stash your laptop (up to 15 inches) in the padded sleeve, your everyday', 'category': "men's clothing", 'image': 'https://fakestoreapi.com/img/81fPKd-2AYL._AC_SL1500_.jpg', 'rating': {'rate': 3.9, 'count': 120}}

# %%
import pandas as pd
df=pd.DataFrame(data)
df.head()
# Out:
#    id                                              title   price  \
# 0   1  Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1   2             Mens Casual Premium Slim Fit T-Shirts    22.30
# 2   3                                 Mens Cotton Jacket   55.99
# 3   4                               Mens Casual Slim Fit   15.99
# 4   5  John Hardy Women's Legends Naga Gold & Silver ...  695.00
#
#                                          description        category  \
# 0  Your perfect pack for everyday use and walks i...  men's clothing
# 1  Slim-fitting style, contrast raglan long sleev...  men's clothing
# 2  great outerwear jackets for Spring/Autumn/Wint...  men's clothing
# 3  The color could be slightly different between ...  men's clothing
# 4  From our Legends Collection, the Naga was insp...        jewelery
#
#                                                image  \
# 0  https://fakestoreapi.com/img/81fPKd-2AYL._AC_S...
# 1  https://fakestoreapi.com/img/71-3HjGNDUL._AC_S...
# 2  https://fakestoreapi.com/img/71li-ujtlUL._AC_U...
# 3  https://fakestoreapi.com/img/71YXzeOuslL._AC_U...
# 4  https://fakestoreapi.com/img/71pWzhdJNwL._AC_U...
#
#                         rating
# 0  {'rate': 3.9, 'count': 120}
# 1  {'rate': 4.1, 'count': 259}
# 2  {'rate': 4.7, 'count': 500}
# 3  {'rate': 2.1, 'count': 430}
# 4  {'rate': 4.6, 'count': 400}

# %%
df['rating_rate'] = df['rating'].apply(lambda x: x['rate'])
df['rating_count'] = df['rating'].apply(lambda x: x['count'])
df.drop('rating', axis=1, inplace=True)

df[['title', 'price', 'category', 'rating_rate', 'rating_count']]
# Out:
#                                                 title   price  \
# 0   Fjallraven - Foldsack No. 1 Backpack, Fits 15 ...  109.95
# 1              Mens Casual Premium Slim Fit T-Shirts    22.30
# 2                                  Mens Cotton Jacket   55.99
# 3                                Mens Casual Slim Fit   15.99
# 4   John Hardy Women's Legends Naga Gold & Silver ...  695.00
# 5                        Solid Gold Petite Micropave   168.00
# 6                          White Gold Plated Princess    9.99
# 7   Pierced Owl Rose Gold Plated Stainless Steel D...   10.99
# 8   WD 2TB Elements Portable External Hard Drive -...   64.00
# 9   SanDisk SSD PLUS 1TB Internal SSD - SATA III 6...  109.00
# 10  Silicon Power 256GB SSD 3D NAND A55 SLC Cache ...  109.00
# 11  WD 4TB Gaming Drive Works with Playstation 4 P...  114.00
# 12  Acer SB220Q bi 21.5 inches Full HD (1920 x 108...  599.00
# 13  Samsung 49-Inch CHG90 144Hz Curved Gaming Moni...  999.99
# 14  BIYLACLESEN Women's 3-in-1 Snowboard Jacket Wi...   56.99
# 15  Lock and Love Women's Removable Hooded Faux Le...   29.95
# 16  Rain Jacket Women Windbreaker Striped Climbing...   39.99
# 17        MBJ Women's Solid Short Sleeve Boat Neck V     9.85
# 18                 Opna Women's Short Sleeve Moisture    7.95
# 19         DANVOUY Womens T Shirt Casual Cotton Short   12.99
#
#             category  rating_rate  rating_count
# 0     men's clothing          3.9           120
# 1     men's clothing          4.1           259
# 2     men's clothing          4.7           500
# 3     men's clothing          2.1           430
# 4           jewelery          4.6           400
# 5           jewelery          3.9            70
# 6           jewelery          3.0           400
# 7           jewelery          1.9           100
# 8        electronics          3.3           203
# 9        electronics          2.9           470
# 10       electronics          4.8           319
# 11       electronics          4.8           400
# 12       electronics          2.9           250
# 13       electronics          2.2           140
# 14  women's clothing          2.6           235
# 15  women's clothing          2.9           340
# 16  women's clothing          3.8           679
# 17  women's clothing          4.7           130
# 18  women's clothing          4.5           146
# 19  women's clothing          3.6           145

# %%
df.to_csv("fakestore.csv",index=False)
